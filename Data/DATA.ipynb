# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
from datetime import datetime
import yfinance as yf
import os
from google.colab import files

# %%
startingDate = '2014-1-1'
endingDate = '2023-1-1'
splitingDate = '2020-1-1'

# Dictionary listing the 5 trading indices considered as testbench
#'Dow Jones' : 'DIA'
Train= yf.download('DIA', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('DIA', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('DIA_2014-1-1_2020-1-1.csv')
Test.to_csv('DIA_2020-1-1_2023-1-1.csv')
files.download('DIA_2014-1-1_2020-1-1.csv')
files.download('DIA_2020-1-1_2023-1-1.csv')


#'S&P 500' : 'SPY'
Train= yf.download('SPY', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('SPY', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('SPY_2014-1-1_2020-1-1.csv')
Test.to_csv('SPY_2020-1-1_2023-1-1.csv')
files.download('SPY_2014-1-1_2020-1-1.csv')
files.download('SPY_2020-1-1_2023-1-1.csv')

#'NASDAQ 100' : 'QQQ'
Train= yf.download('QQQ', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('QQQ', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('QQQ_2014-1-1_2020-1-1.csv')
Test.to_csv('QQQ_2020-1-1_2023-1-1.csv')
files.download('QQQ_2014-1-1_2020-1-1.csv')
files.download('QQQ_2020-1-1_2023-1-1.csv')


#'FTSE 100' : 'EZU'
Train= yf.download('EZU', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('EZU', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('EZU_2014-1-1_2020-1-1.csv')
Test.to_csv('EZU_2020-1-1_2023-1-1.csv')
files.download('EZU_2014-1-1_2020-1-1.csv')
files.download('EZU_2020-1-1_2023-1-1.csv')


#'Nikkei 225' : 'EWJ',
Train= yf.download('EWJ', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('EWJ', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('EWJ_2014-1-1_2020-1-1.csv')
Test.to_csv('EWJ_2020-1-1_2023-1-1.csv')
files.download('EWJ_2014-1-1_2020-1-1.csv')
files.download('EWJ_2020-1-1_2023-1-1.csv')



# Dictionary listing the 27 company stocks considered as testbench
#'Google' : 'GOOGL'
Train= yf.download('GOOGL', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('GOOGL', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('GOOGL_2014-1-1_2020-1-1.csv')
Test.to_csv('GOOGL_2020-1-1_2023-1-1.csv')
files.download('GOOGL_2014-1-1_2020-1-1.csv')
files.download('GOOGL_2020-1-1_2023-1-1.csv')

# %%
#'Toyota' : '7203.T',
Train= yf.download('7203.T', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('7203.T', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('7203.T_2014-1-1_2020-1-1.csv')
Test.to_csv('7203.T_2020-1-1_2023-1-1.csv')
files.download('7203.T_2014-1-1_2020-1-1.csv')
files.download('7203.T_2020-1-1_2023-1-1.csv')

#'Coca Cola' : 'KO',
Train= yf.download('KO', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('KO', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('KO_2014-1-1_2020-1-1.csv')
Test.to_csv('KO_2020-1-1_2023-1-1.csv')
files.download('KO_2014-1-1_2020-1-1.csv')
files.download('KO_2020-1-1_2023-1-1.csv')


#'AB InBev' : 'ABI.BR',
Train= yf.download('ABI.BR', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('ABI.BR', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('ABI.BR_2014-1-1_2020-1-1.csv')
Test.to_csv('ABI.BR_2020-1-1_2023-1-1.csv')
files.download('ABI.BR_2014-1-1_2020-1-1.csv')
files.download('ABI.BR_2020-1-1_2023-1-1.csv')


#'Kirin' : '2503.T'
Train= yf.download('2503.T', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('2503.T', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('2503.T_2014-1-1_2020-1-1.csv')
Test.to_csv('2503.T_2020-1-1_2023-1-1.csv')
files.download('2503.T_2014-1-1_2020-1-1.csv')
files.download('2503.T_2020-1-1_2023-1-1.csv')

# %%
#'Apple' : 'AAPL',
Train= yf.download('AAPL', start=startingDate, end=splitingDate, interval='1d')
valition= yf.download('AAPL', start= '2018-1-1', end=splitingDate, interval='1d')
Test=  yf.download('AAPL', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
valition.index.names = ['Timestamp']
valition = valition[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('AAPL_2014-1-1_2020-1-1.csv')
valition.to_csv('AAPL_2018-1-1_2020-1-1.csv')
Test.to_csv('AAPL_2020-1-1_2023-1-1.csv')
files.download('AAPL_2014-1-1_2020-1-1.csv')
files.download('AAPL_2018-1-1_2020-1-1.csv')
files.download('AAPL_2020-1-1_2023-1-1.csv')


#'Facebook' : 'META',
Train= yf.download('META', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('META', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('META_2014-1-1_2020-1-1.csv')
Test.to_csv('META_2020-1-1_2023-1-1.csv')
files.download('META_2014-1-1_2020-1-1.csv')
files.download('META_2020-1-1_2023-1-1.csv')

#'Amazon' : 'AMZN',
Train= yf.download('AMZN', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('AMZN', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('AMZN_2014-1-1_2020-1-1.csv')
Test.to_csv('AMZN_2020-1-1_2023-1-1.csv')
files.download('AMZN_2014-1-1_2020-1-1.csv')
files.download('AMZN_2020-1-1_2023-1-1.csv')

#'Microsoft' : 'MSFT',
Train= yf.download('MSFT', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('MSFT', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('MSFT_2014-1-1_2020-1-1.csv')
Test.to_csv('MSFT_2020-1-1_2023-1-1.csv')
files.download('MSFT_2014-1-1_2020-1-1.csv')
files.download('MSFT_2020-1-1_2023-1-1.csv')

# %%
#'Nokia' : 'NOK',
Train= yf.download('NOK', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('NOK', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('NOK_2014-1-1_2020-1-1.csv')
Test.to_csv('NOK_2020-1-1_2023-1-1.csv')
files.download('NOK_2014-1-1_2020-1-1.csv')
files.download('NOK_2020-1-1_2023-1-1.csv')

#'Philips' : 'PHIA.AS',
Train= yf.download('PHIA.AS', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('PHIA.AS', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('PHIA.AS_2014-1-1_2020-1-1.csv')
Test.to_csv('PHIA.AS_2020-1-1_2023-1-1.csv')
files.download('PHIA.AS_2014-1-1_2020-1-1.csv')
files.download('PHIA.AS_2020-1-1_2023-1-1.csv')


#'Siemens' : 'SIE.DE',
Train= yf.download('SIE.DE', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('SIE.DE', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('SIE.DE_2014-1-1_2020-1-1.csv')
Test.to_csv('SIE.DE_2020-1-1_2023-1-1.csv')
files.download('SIE.DE_2014-1-1_2020-1-1.csv')
files.download('SIE.DE_2020-1-1_2023-1-1.csv')


#'Baidu' : 'BIDU',
Train= yf.download('BIDU', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('BIDU', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('BIDU_2014-1-1_2020-1-1.csv')
Test.to_csv('BIDU_2020-1-1_2023-1-1.csv')
files.download('BIDU_2014-1-1_2020-1-1.csv')
files.download('BIDU_2020-1-1_2023-1-1.csv')

# %%
#'Alibaba' : 'BABA',
Train= yf.download('BABA', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('BABA', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('BABA_2014-1-1_2020-1-1.csv')
Test.to_csv('BABA_2020-1-1_2023-1-1.csv')
files.download('BABA_2014-1-1_2020-1-1.csv')
files.download('BABA_2020-1-1_2023-1-1.csv')


#'Tencent' : '0700.HK',
Train= yf.download('0700.HK', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('0700.HK', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('0700.HK_2014-1-1_2020-1-1.csv')
Test.to_csv('0700.HK_2020-1-1_2023-1-1.csv')
files.download('0700.HK_2014-1-1_2020-1-1.csv')
files.download('0700.HK_2020-1-1_2023-1-1.csv')


#'Sony' : '6758.T',
Train= yf.download('6758.T', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('6758.T', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('6758.T_2014-1-1_2020-1-1.csv')
Test.to_csv('6758.T_2020-1-1_2023-1-1.csv')
files.download('6758.T_2014-1-1_2020-1-1.csv')
files.download('6758.T_2020-1-1_2023-1-1.csv')

#'JPMorgan Chase' : 'JPM',
Train= yf.download('JPM', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('JPM', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('JPM_2014-1-1_2020-1-1.csv')
Test.to_csv('JPM_2020-1-1_2023-1-1.csv')
files.download('JPM_2014-1-1_2020-1-1.csv')
files.download('JPM_2020-1-1_2023-1-1.csv')

#'HSBC' : 'HSBC',
Train= yf.download('HSBC', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('HSBC', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('HSBC_2014-1-1_2020-1-1.csv')
Test.to_csv('HSBC_2020-1-1_2023-1-1.csv')
files.download('HSBC_2014-1-1_2020-1-1.csv')
files.download('HSBC_2020-1-1_2023-1-1.csv')

# %%
#'CCB' : '0939.HK',
Train= yf.download('0939.HK', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('0939.HK', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('0939.HK_2014-1-1_2020-1-1.csv')
Test.to_csv('0939.HK_2020-1-1_2023-1-1.csv')
files.download('0939.HK_2014-1-1_2020-1-1.csv')
files.download('0939.HK_2020-1-1_2023-1-1.csv')


#'ExxonMobil' : 'XOM',
Train= yf.download('XOM', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('XOM', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('XOM_2014-1-1_2020-1-1.csv')
Test.to_csv('XOM_2020-1-1_2023-1-1.csv')
files.download('XOM_2014-1-1_2020-1-1.csv')
files.download('XOM_2020-1-1_2023-1-1.csv')


#'Shell' : 'SHELL.AS',
Train= yf.download('SHELL.AS', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('SHELL.AS', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('SHELL.AS_2014-1-1_2020-1-1.csv')
Test.to_csv('SHELL.AS_2020-1-1_2023-1-1.csv')
files.download('SHELL.AS_2014-1-1_2020-1-1.csv')
files.download('SHELL.AS_2020-1-1_2023-1-1.csv')

#'PetroChina' : 'PCCYF',
Train= yf.download('PCCYF', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('PCCYF', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('PCCYF_2014-1-1_2020-1-1.csv')
Test.to_csv('PCCYF_2020-1-1_2023-1-1.csv')
files.download('PCCYF_2014-1-1_2020-1-1.csv')
files.download('PCCYF_2020-1-1_2023-1-1.csv')


#'Tesla' : 'TSLA',
Train= yf.download('TSLA', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('TSLA', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('TSLA_2014-1-1_2020-1-1.csv')
Test.to_csv('TSLA_2020-1-1_2023-1-1.csv')
files.download('TSLA_2014-1-1_2020-1-1.csv')
files.download('TSLA_2020-1-1_2023-1-1.csv')


#'Volkswagen' : 'VOW3.DE',
Train= yf.download('VOW3.DE', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('VOW3.DE', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('VOW3.DE_2014-1-1_2020-1-1.csv')
Test.to_csv('VOW3.DE_2020-1-1_2023-1-1.csv')
files.download('VOW3.DE_2014-1-1_2020-1-1.csv')
files.download('VOW3.DE_2020-1-1_2023-1-1.csv')

# %%
#'Bitcoin': ''BTC-USD'',
Train= yf.download('BTC-USD', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('BTC-USD', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('BTC-USD_2014-1-1_2020-1-1.csv')
Test.to_csv('BTC-USD_2020-1-1_2023-1-1.csv')
files.download('BTC-USD_2014-1-1_2020-1-1.csv')
files.download('BTC-USD_2020-1-1_2023-1-1.csv')

#'Binance': ''BNB-USD'',
Train= yf.download('BNB-USD', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('BNB-USD', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('BNB-USD_2014-1-1_2020-1-1.csv')
Test.to_csv('BNB-USD_2020-1-1_2023-1-1.csv')
files.download('BNB-USD_2014-1-1_2020-1-1.csv')
files.download('BNB-USD_2020-1-1_2023-1-1.csv')

#'Litecoin': 'LTC-USD',
Train= yf.download('LTC-USD', start=startingDate, end=splitingDate, interval='1d')
Test=  yf.download('LTC-USD', start=splitingDate, end=endingDate, interval='1d')
Train.index.names = ['Timestamp']
Train = Train[['Open', 'High', 'Low', 'Close', 'Volume']]
Test.index.names = ['Timestamp']
Test = Test[['Open', 'High', 'Low', 'Close', 'Volume']]
Train.to_csv('LTC-USD_2014-1-1_2020-1-1.csv')
Test.to_csv('LTC-USD_2020-1-1_2023-1-1.csv')
files.download('LTC-USD_2014-1-1_2020-1-1.csv')
files.download('LTC-USD_2020-1-1_2023-1-1.csv')
